# %%
#!pip install pandas(if panda was not isntalled)
import pandas as pd

# %%
file=open("info.csv",'x')
file.close()

# %%
info=" "
file=open("info.csv",'w')
file.write('name,age,add\n')
n=int(input('enter n='))
for i in range(n):
    name=input('Enter name=')
    age=int(input('enter age='))
    add=input('enter add=')
    info=info+f"{name},{age},{add}\n"

file.write(info)
file.close()
# Out:
# enter n= 6
# Enter name= rAM
# enter age= 23
# enter add= KTM
# Enter name= SHYam
# enter age= 12
# enter add= bhr
# Enter name= hari
# enter age= 14
# enter add= pkr
# Enter name= sita
# enter age= 56
# enter add= lalitpur
# Enter name= gita
# enter age= 24
# enter add= lumbini
# Enter name= mita
# enter age= 98
# enter add= gorkha

# %%
import pandas as pd
df=pd.read_csv('info.csv')
df
# Out:
#     name  age        add
# 0    rAM   23        KTM
# 1  SHYam   12        bhr
# 2   hari   14        pkr
# 3   sita   56   lalitpur
# 4   gita   24    lumbini
# 5   mita   98     gorkha

# %%
df=pd.read_csv('info.csv',)
#df.head()
df.head(3)
# Out:
#     name  age   add
# 0    rAM   23   KTM
# 1  SHYam   12   bhr
# 2   hari   14   pkr

# %%
df=pd.read_csv('info.csv')
df.tail()
# Out:
#     name  age        add
# 1  SHYam   12        bhr
# 2   hari   14        pkr
# 3   sita   56   lalitpur
# 4   gita   24    lumbini
# 5   mita   98     gorkha

# %%
#columns haru select garna
df=pd.read_csv('info.csv',usecols=['name','add'])
df
# Out:
#     name        add
# 0    rAM        KTM
# 1  SHYam        bhr
# 2   hari        pkr
# 3   sita   lalitpur
# 4   gita    lumbini
# 5   mita     gorkha

# %%
df=pd.read_csv('info.csv',usecols=['name','age'])
df
# Out:
#     name  age
# 0    rAM   23
# 1  SHYam   12
# 2   hari   14
# 3   sita   56
# 4   gita   24
# 5   mita   98

# %%
df=pd.read_csv('info.csv')
df
# Out:
#     name  age        add
# 0    rAM   23        KTM
# 1  SHYam   12        bhr
# 2   hari   14        pkr
# 3   sita   56   lalitpur
# 4   gita   24    lumbini
# 5   mita   98     gorkha

# %%
df.iloc[1:5]
# Out:
#     name  age        add
# 1  SHYam   12        bhr
# 2   hari   14        pkr
# 3   sita   56   lalitpur
# 4   gita   24    lumbini

# %%
df['add']
# Out:
# 0          KTM
# 1          bhr
# 2          pkr
# 3     lalitpur
# 4      lumbini
# 5       gorkha
# Name: add, dtype: object

# %%
df['add']=='KTM'
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# Name: add, dtype: bool

# %%
df[df['add'] =="bhr "]
# Out:
# Empty DataFrame
# Columns: [name, age, add]
# Index: []

# %%
df[(df['add'] == 'KTM ')& df['age'] >=30]
# Out:
# Empty DataFrame
# Columns: [name, age, add]
# Index: []

# %%
info=" "
file=open("info.csv",'w')
file.write('name,age,add\n')
n=int(input('enter n='))
for i in range(n):
    name=input('Enter name=')
    age=int(input('enter age='))
    add=input('enter add=')
    info=info+f"{name},{age},{add}\n"

file.write(info)
file.close()
# Out:
# enter n= 6
# Enter name= ram
# enter age= 45
# enter add= kathmandu
# Enter name= shya,
# enter age= 24
# enter add= lalitpur
# Enter name= hari
# enter age= 46
# enter add= bhaktapur
# Enter name= sita
# enter age= 26
# enter add= bharatpur
# Enter name= gita
# enter age= 89
# enter add= kathmandu
# Enter name= mita
# enter age= 46
# enter add= chitwan

# %%
df['add']=='kathmandu'
df
# Out:
#     name  age        add
# 0    rAM   23        KTM
# 1  SHYam   12        bhr
# 2   hari   14        pkr
# 3   sita   56   lalitpur
# 4   gita   24    lumbini
# 5   mita   98     gorkha

# %%
info=" "
file=open("info.csv",'w')
file.write('name,age,add\n')
n=int(input('enter n='))
for i in range(n):
    name=input('Enter name=')
    age=int(input('enter age='))
    add=input('enter add=')
    info=info+f"{name},{age},{add}\n"

file.write(info)
file.close()
# Out:
# enter n= 6
# Enter name= ram
# enter age= 45
# enter add= kathmandu
# Enter name= shyam
# enter age= 54
# enter add= bhaktapur
# Enter name= hari
# enter age= 67
# enter add= kalanki
# Enter name= sita
# enter age= 56
# enter add= balaju
# Enter name= gita
# enter age= 98
# enter add= balkhu
# Enter name= mita
# enter age= 87
# enter add= sanepa

# %%
import pandas as pd
df=pd.read_csv('info.csv')
df
# Out:
#     name  age        add
# 0    ram   45  kathmandu
# 1  shyam   54  bhaktapur
# 2   hari   67    kalanki
# 3   sita   56     balaju
# 4   gita   98     balkhu
# 5   mita   87     sanepa

# %%
df['add']=='kathmandu'
df
# Out:
#     name  age        add
# 0    ram   45  kathmandu
# 1  shyam   54  bhaktapur
# 2   hari   67    kalanki
# 3   sita   56     balaju
# 4   gita   98     balkhu
# 5   mita   87     sanepa

# %%
df['add']=='kathmandu'
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# Name: add, dtype: bool

# %%
df['sn']=[i for in in range(1,7)

# %%
df[(df['add']=='kathmandu')&(df['age']>=10)]
# Out:
#    name  age        add
# 0   ram   45  kathmandu

# %%
df=pd.read_csv('info.csv')
df['sn']=[i for i in range(1,7)]
df
# Out:
#     name  age        add  sn
# 0    ram   45  kathmandu   1
# 1  shyam   54  bhaktapur   2
# 2   hari   67    kalanki   3
# 3   sita   56     balaju   4
# 4   gita   98     balkhu   5
# 5   mita   87     sanepa   6

# %%
['sn']=[i for i in range(1,7)]
# Out:
#   Cell In[12], line 1
#     ['sn']=[i for i in range(1,7)]
#      ^
# SyntaxError: cannot assign to literal

# %%
# to add new row
data={'sn':[7,8],'age':[22,33],'name':['akash','ayush'],'add':['kathmandu','lalitpur']}
data
# Out:
# {'sn': [7, 8],
#  'age': [22, 33],
#  'name': ['akash', 'ayush'],
#  'add': ['kathmandu', 'lalitpur']}

# %%
df1=pd.DataFrame(data)
df1
# Out:
#    sn  age   name        add
# 0   7   22  akash  kathmandu
# 1   8   33  ayush   lalitpur

# %%
df=pd.concat([df,df1])
df
# Out:
#     name  age        add  sn
# 0    ram   45  kathmandu   1
# 1  shyam   54  bhaktapur   2
# 2   hari   67    kalanki   3
# 3   sita   56     balaju   4
# 4   gita   98     balkhu   5
# 5   mita   87     sanepa   6
# 0  akash   22  kathmandu   7
# 1  ayush   33   lalitpur   8

# %%
df.to_csv('new_data.csv')

# %%
#index_col= repeat nahune data lai rakhne
df=pd.read_csv('new_data.csv',usecols=['sn','name','age','add'], index_col='sn')
df
# Out:
#      name  age        add
# sn
# 1     ram   45  kathmandu
# 2   shyam   54  bhaktapur
# 3    hari   67    kalanki
# 4    sita   56     balaju
# 5    gita   98     balkhu
# 6    mita   87     sanepa
# 7   akash   22  kathmandu
# 8   ayush   33   lalitpur

# %%
#kunai value lai delete rakhna
df.drop([3,4], axis=0)
# Out:
#      name  age        add
# sn
# 1     ram   45  kathmandu
# 2   shyam   54  bhaktapur
# 5    gita   98     balkhu
# 6    mita   87     sanepa
# 7   akash   22  kathmandu
# 8   ayush   33   lalitpur

# %%
df.drop(['age'], axis=1)
# Out:
#      name        add
# sn
# 1     ram  kathmandu
# 2   shyam  bhaktapur
# 3    hari    kalanki
# 4    sita     balaju
# 5    gita     balkhu
# 6    mita     sanepa
# 7   akash  kathmandu
# 8   ayush   lalitpur
